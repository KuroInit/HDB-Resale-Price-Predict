# %% [markdown]
# # Import necessary libraries

# %%
import torch
import os
import wget
import json
import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt 
import xgboost as xgb
import math

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import LabelEncoder
from pytorch_tabnet.tab_model import TabNetRegressor
from pathlib import Path

np.random.seed(0)
sb.set() 
model = TabNetRegressor(device_name='cuda')
# Out:
# c:\Users\User\AppData\Local\Programs\Python\Python310\lib\site-packages\pytorch_tabnet\abstract_model.py:82: UserWarning: Device used : cpu
#   warnings.warn(f"Device used : {self.device}")

# %%
csv_data = pd.read_csv('data/clean_data/final_data.csv')

with open('data/clean_data/encoding_mappings.json', 'r') as fp:
    encoding_mappings = json.load(fp)

final_data = csv_data[csv_data['Year'] >= 2000]
final_data
# Out:
#         Year  Month  lease_commence_date  floor_area_sqm  average_storey  \
# 0       2000      1                 1986            69.0             8.0
# 1       2000      1                 1970            66.0             5.0
# 2       2000      1                 1970            72.0            17.0
# 3       2000      1                 1970            72.0             5.0
# 4       2000      1                 1970            72.0             2.0
# ...      ...    ...                  ...             ...             ...
# 633997  2024      3                 1990           105.0             2.0
# 633998  2024      3                 1985            91.0            11.0
# 633999  2024      3                 1978            98.0             8.0
# 634000  2024      3                 2019            92.0             5.0
# 634001  2024      3                 1987           142.0             8.0
#
#         resale_price_adjusted  town  flat_type  flat_model
# 0               219202.861724     1          2           6
# 1               216220.509864     6          2           6
# 2               310164.593460     6          2           6
# 3               277358.722998     6          2           6
# 4               271394.019278     6          2           6
# ...                       ...   ...        ...         ...
# 633997          538888.000000    12          3           5
# 633998          538000.000000    12          3           3
# 633999          538000.000000    12          3           3
# 634000          573000.000000    12          3           5
# 634001          780000.000000     2          5           9
#
# [634002 rows x 9 columns]

# %%
for category, mappings in encoding_mappings.items():
    print(f"{category}:")
    for key, value in mappings.items():
        print(f"  {key}: {value}")
    print()
# Out:
# town:
#   GEYLANG: 0
#   ANG MO KIO: 1
#   YISHUN: 2
#   BEDOK: 3
#   TOA PAYOH: 4
#   BUKIT BATOK: 5
#   QUEENSTOWN: 6
#   CLEMENTI: 7
#   JURONG EAST: 8
#   JURONG WEST: 9
#   WOODLANDS: 10
#   KALLANG/WHAMPOA: 11
#   HOUGANG: 12
#   BUKIT PANJANG: 13
#   SERANGOON: 14
#   CHOA CHU KANG: 15
#   SEMBAWANG: 16
#   CENTRAL AREA: 17
#   TAMPINES: 18
#   MARINE PARADE: 19
#   BUKIT MERAH: 20
#   SENGKANG: 21
#   PASIR RIS: 22
#   PUNGGOL: 23
#   BISHAN: 24
#   BUKIT TIMAH: 25
#
# flat_type:
#   1 ROOM: 0
#   2 ROOM: 1
#   3 ROOM: 2
#   4 ROOM: 3
#   5 ROOM: 4
#   EXECUTIVE: 5
#   MULTI-GENERATION: 6
#
# flat_model:
#   Standard: 0
#   2-room: 1
#   Simplified: 2
#   New Generation: 3
#   Model A2: 4
#   Model A: 5
#   Improved: 6
#   Premium Apartment: 7
#   Adjoined flat: 8
#   Apartment: 9
#   Model A-Maisonette: 10
#   Improved-Maisonette: 11
#   Maisonette: 12
#   Multi Generation: 13
#   3Gen: 14
#   Terrace: 15
#   Premium Maisonette: 16
#   DBSS: 17
#   Type S1: 18
#   Premium Apartment Loft: 19
#   Type S2: 20

# %%
def encode_new_input(new_input, encoding_mappings):
# If new_input is a dictionary, convert it to a DataFrame
    if isinstance(new_input, dict):
        new_input = pd.DataFrame([new_input])
    
    # If new_input is a list of dictionaries, convert it to a DataFrame
    elif isinstance(new_input, list):
        new_input = pd.DataFrame(new_input)

    # Ensure that new_input is a DataFrame at this point
    if not isinstance(new_input, pd.DataFrame):
        raise ValueError("new_input must be a pandas DataFrame, a dictionary, or a list of dictionaries.")    
    new_input_encoded = new_input.copy()
    for column, mapping in encoding_mappings.items():
        if column in new_input.columns:
            # Apply the mapping to the column
            new_input_encoded[column] = new_input[column].map(mapping)
            # Fill in NaN values if the category was not seen during training
            if new_input_encoded[column].isna().any():
                unknown_rank = np.median(list(mapping.values()))
                # Use direct assignment instead of inplace=True
                new_input_encoded[column] = new_input_encoded[column].fillna(unknown_rank)
    
    return new_input_encoded

# %%
features = ['Year','Month','floor_area_sqm', 'lease_commence_date', 'average_storey','town', 'flat_type', 'flat_model']
target = 'resale_price_adjusted'

# %% [markdown]
# # Employing basic linearing regression model with the numerical data

# %%
X_train, X_test, y_train, y_test = train_test_split(final_data[features], final_data[target], test_size=0.1, random_state=42)

linreg = LinearRegression()
linreg.fit(X_train, y_train)

xgbreg = xgb.XGBRegressor(
    objective='reg:squarederror', 
    booster='gbtree', 
    reg_alpha=0.1, 
    reg_lambda=0.1)
xgbreg.fit(X_train,y_train)

y_test_pred_linReg = linreg.predict(X_test)
y_test_pred_xgb = xgbreg.predict(X_test)

print("Goodness of Fit on Test Dataset:")
print()
print("Linear Regression Model:")
print("Explained Variance (R^2):", r2_score(y_test, y_test_pred_linReg))
print("Mean Squared Error (MSE):", mean_squared_error(y_test, y_test_pred_linReg))
print()

print("XGBoost Model:")
print("Explained Variance (R^2):", r2_score(y_test, y_test_pred_xgb))
print("Mean Squared Error (MSE):", mean_squared_error(y_test, y_test_pred_xgb))
print()

plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.scatter(y_test, y_test_pred_linReg, alpha= 0.5)
plt.plot(y_test, y_test, 'r--', linewidth=2)
plt.xlabel("True values of the Response Variable (Test)")
plt.ylabel("Predicted values of the Response Variable (Test)")
plt.title("Linear Regression Model")

plt.subplot(1, 2, 2)
plt.scatter(y_test, y_test_pred_xgb, alpha= 0.5)
plt.plot(y_test, y_test, 'r--', linewidth=2)
plt.xlabel("True values of the Response Variable (Test)")
plt.ylabel("Predicted values of the Response Variable (Test)")
plt.title("XGBoost Model")

plt.tight_layout()
plt.show()
# Out:
# Goodness of Fit on Test Dataset:
#
# Linear Regression Model:
# Explained Variance (R^2): 0.7001593205392791
# Mean Squared Error (MSE): 8034973341.5547495
#
# XGBoost Model:
# Explained Variance (R^2): 0.9568476342909792
# Mean Squared Error (MSE): 1156374474.3395467

# %%
from scipy import stats
from scipy.special import inv_boxcox

# Apply Box-Cox transformation
y_train_boxcox, lambda_boxcox = stats.boxcox(y_train)
y_test_boxcox = stats.boxcox(y_test, lmbda=lambda_boxcox) 

# Split the transformed y_train for validation purposes
X_train_tabnet, X_valid_tabnet, y_train_tabnet_boxcox, y_valid_tabnet_boxcox = train_test_split(
                                                                                        X_train, 
                                                                                        y_train_boxcox, 
                                                                                        test_size=0.1, random_state=42)

# Convert to numpy values for TabNet
X_train_tabnet_values = X_train_tabnet.values
X_valid_tabnet_values = X_valid_tabnet.values
y_train_tabnet_boxcox_values = y_train_tabnet_boxcox.reshape(-1, 1)
y_valid_tabnet_boxcox_values = y_valid_tabnet_boxcox.reshape(-1, 1)

# Train a linear regression model after Box-Cox transformation
linreg_withBoxCox = LinearRegression()
linreg_withBoxCox.fit(X_train, y_train_boxcox)

# Train a XGBoost model after Box-Cox transformation
xgbreg_withBoxCox = xgb.XGBRegressor(
    objective='reg:squarederror', 
    booster='gbtree', 
    reg_alpha=0.1, 
    reg_lambda=0.1)
xgbreg_withBoxCox.fit(X_train, y_train_boxcox)

y_test_pred_linReg_boxcox = linreg_withBoxCox.predict(X_test)
y_test_pred_xgb_boxcox =  xgbreg_withBoxCox.predict(X_test)
# Inverse transform predictions from the Box-Cox scale to the original scale
y_test_pred_linReg_original_scale = inv_boxcox(y_test_pred_linReg_boxcox, lambda_boxcox)
y_test_pred_xgb_original_scale = inv_boxcox(y_test_pred_xgb_boxcox, lambda_boxcox)

# Evaluate the Linear Regression model on the original scale
print("Linear Regression Model (with Box-Cox transformation):")
print("Explained Variance (R^2):", r2_score(y_test, y_test_pred_linReg_original_scale))
print("Root Mean Squared Error (RMSE):", math.sqrt(mean_squared_error(y_test, y_test_pred_linReg_original_scale)))
print()

# Evaluate the XGBoost model on the original scale
print("XGBoost Model (with Box-Cox transformation):")
print("Explained Variance (R^2):", r2_score(y_test, y_test_pred_xgb_original_scale))
print("Root Mean Squared Error (RMSE):", math.sqrt(mean_squared_error(y_test, y_test_pred_xgb_original_scale)))
print()
# Out:
# Linear Regression Model (with Box-Cox transformation):
# Explained Variance (R^2): 0.7003549169166182
# Root Mean Squared Error (RMSE): 89608.7710683115
#
# XGBoost Model (with Box-Cox transformation):
# Explained Variance (R^2): 0.955981841427905
# Root Mean Squared Error (RMSE): 34344.9492299273

# %%
# Train a TabNet model after Box-Cox transformation
tabnetReg = TabNetRegressor()
max_epochs = 200

tabnetReg.fit(
    X_train_tabnet_values, 
    y_train_tabnet_boxcox_values,
    eval_set=[(X_train_tabnet_values, y_train_tabnet_boxcox_values), 
              (X_valid_tabnet_values, y_valid_tabnet_boxcox_values)],
    eval_name=['train', 'valid'],
    eval_metric=['mae', 'rmse'],
    max_epochs=max_epochs,
    patience=20,
    batch_size=4096,
    virtual_batch_size=512,
    num_workers=0,
    drop_last=False
)
# Out:
# c:\Users\User\AppData\Local\Programs\Python\Python310\lib\site-packages\pytorch_tabnet\abstract_model.py:82: UserWarning: Device used : cpu
#   warnings.warn(f"Device used : {self.device}")
# epoch 0  | loss: 161.77101| train_mae: 13.05819| train_rmse: 15.30564| valid_mae: 13.08313| valid_rmse: 15.33158|  0:00:45s
# epoch 1  | loss: 0.82008 | train_mae: 7.82777 | train_rmse: 9.04234 | valid_mae: 7.82912 | valid_rmse: 9.05085 |  0:01:39s
# epoch 2  | loss: 0.74836 | train_mae: 4.07415 | train_rmse: 4.4595  | valid_mae: 4.07708 | valid_rmse: 4.46136 |  0:02:32s
# epoch 3  | loss: 0.69342 | train_mae: 1.81453 | train_rmse: 2.10833 | valid_mae: 1.81387 | valid_rmse: 2.10707 |  0:03:17s
# epoch 4  | loss: 0.67921 | train_mae: 0.74946 | train_rmse: 0.9498  | valid_mae: 0.75297 | valid_rmse: 0.95457 |  0:03:57s
# epoch 5  | loss: 0.70318 | train_mae: 0.61102 | train_rmse: 0.79257 | valid_mae: 0.61055 | valid_rmse: 0.79191 |  0:04:34s
# epoch 6  | loss: 0.63738 | train_mae: 0.58766 | train_rmse: 0.75987 | valid_mae: 0.58912 | valid_rmse: 0.76142 |  0:05:15s
# epoch 7  | loss: 0.58346 | train_mae: 0.53739 | train_rmse: 0.72475 | valid_mae: 0.53751 | valid_rmse: 0.72568 |  0:05:51s
# epoch 8  | loss: 0.54697 | train_mae: 0.53754 | train_rmse: 0.72691 | valid_mae: 0.53746 | valid_rmse: 0.72757 |  0:06:28s
# epoch 9  | loss: 0.572   | train_mae: 0.55264 | train_rmse: 0.71851 | valid_mae: 0.55393 | valid_rmse: 0.71951 |  0:07:05s
# epoch 10 | loss: 0.5123  | train_mae: 0.51545 | train_rmse: 0.69002 | valid_mae: 0.51679 | valid_rmse: 0.69119 |  0:07:48s
# epoch 11 | loss: 0.50193 | train_mae: 0.50481 | train_rmse: 0.68228 | valid_mae: 0.50754 | valid_rmse: 0.68496 |  0:08:28s
# epoch 12 | loss: 0.48554 | train_mae: 0.5072  | train_rmse: 0.68003 | valid_mae: 0.5112  | valid_rmse: 0.68369 |  0:09:03s
# epoch 13 | loss: 0.48157 | train_mae: 0.4968  | train_rmse: 0.66168 | valid_mae: 0.49854 | valid_rmse: 0.6632  |  0:09:37s
# epoch 14 | loss: 0.47256 | train_mae: 0.48262 | train_rmse: 0.64541 | valid_mae: 0.48389 | valid_rmse: 0.64694 |  0:10:11s
# epoch 15 | loss: 0.45872 | train_mae: 0.4886  | train_rmse: 0.65606 | valid_mae: 0.49246 | valid_rmse: 0.66063 |  0:10:47s
# epoch 16 | loss: 0.46215 | train_mae: 0.49818 | train_rmse: 0.66841 | valid_mae: 0.49993 | valid_rmse: 0.66966 |  0:11:28s
# epoch 17 | loss: 0.45344 | train_mae: 0.48819 | train_rmse: 0.65011 | valid_mae: 0.49158 | valid_rmse: 0.65355 |  0:12:07s
# epoch 18 | loss: 0.47264 | train_mae: 0.49715 | train_rmse: 0.66254 | valid_mae: 0.49816 | valid_rmse: 0.66421 |  0:12:46s
# epoch 19 | loss: 0.44618 | train_mae: 0.49607 | train_rmse: 0.64794 | valid_mae: 0.49745 | valid_rmse: 0.64993 |  0:13:23s
# epoch 20 | loss: 0.45521 | train_mae: 0.47863 | train_rmse: 0.6317  | valid_mae: 0.48016 | valid_rmse: 0.63384 |  0:14:05s
# epoch 21 | loss: 0.42663 | train_mae: 0.48789 | train_rmse: 0.64125 | valid_mae: 0.4906  | valid_rmse: 0.64488 |  0:14:43s
# epoch 22 | loss: 0.42438 | train_mae: 0.46716 | train_rmse: 0.6178  | valid_mae: 0.46983 | valid_rmse: 0.62118 |  0:15:24s
# epoch 23 | loss: 0.41849 | train_mae: 0.47565 | train_rmse: 0.6232  | valid_mae: 0.47838 | valid_rmse: 0.62625 |  0:16:05s
# epoch 24 | loss: 0.39702 | train_mae: 0.45642 | train_rmse: 0.5995  | valid_mae: 0.45886 | valid_rmse: 0.60326 |  0:16:43s
# epoch 25 | loss: 0.38278 | train_mae: 0.49156 | train_rmse: 0.64713 | valid_mae: 0.49284 | valid_rmse: 0.64822 |  0:17:27s
# epoch 26 | loss: 0.37899 | train_mae: 0.48007 | train_rmse: 0.62295 | valid_mae: 0.48158 | valid_rmse: 0.62558 |  0:18:06s
# epoch 27 | loss: 0.37152 | train_mae: 0.44069 | train_rmse: 0.589   | valid_mae: 0.44266 | valid_rmse: 0.59009 |  0:18:43s
# epoch 28 | loss: 0.36864 | train_mae: 0.42597 | train_rmse: 0.56729 | valid_mae: 0.42834 | valid_rmse: 0.5706  |  0:19:22s
# epoch 29 | loss: 0.35121 | train_mae: 0.42351 | train_rmse: 0.56379 | valid_mae: 0.42699 | valid_rmse: 0.56724 |  0:20:03s
# epoch 30 | loss: 0.34403 | train_mae: 0.4186  | train_rmse: 0.55328 | valid_mae: 0.42293 | valid_rmse: 0.55693 |  0:20:43s
# epoch 31 | loss: 0.33693 | train_mae: 0.40247 | train_rmse: 0.53737 | valid_mae: 0.40541 | valid_rmse: 0.53993 |  0:21:20s
# epoch 32 | loss: 0.39021 | train_mae: 0.58642 | train_rmse: 0.76955 | valid_mae: 0.59161 | valid_rmse: 0.77614 |  0:22:09s
# epoch 33 | loss: 0.40017 | train_mae: 0.44219 | train_rmse: 0.56971 | valid_mae: 0.44697 | valid_rmse: 0.57581 |  0:22:50s
# epoch 34 | loss: 0.34106 | train_mae: 0.40662 | train_rmse: 0.53525 | valid_mae: 0.41219 | valid_rmse: 0.54206 |  0:23:34s
# epoch 35 | loss: 0.2999  | train_mae: 0.38047 | train_rmse: 0.50003 | valid_mae: 0.38473 | valid_rmse: 0.50555 |  0:24:11s
# epoch 36 | loss: 0.295   | train_mae: 0.3692  | train_rmse: 0.48588 | valid_mae: 0.37402 | valid_rmse: 0.49241 |  0:24:49s
# epoch 37 | loss: 0.29247 | train_mae: 0.36873 | train_rmse: 0.48616 | valid_mae: 0.37323 | valid_rmse: 0.49224 |  0:25:26s
# epoch 38 | loss: 0.26727 | train_mae: 0.36916 | train_rmse: 0.48796 | valid_mae: 0.37313 | valid_rmse: 0.49339 |  0:26:05s
# epoch 39 | loss: 0.27878 | train_mae: 0.38719 | train_rmse: 0.50734 | valid_mae: 0.39246 | valid_rmse: 0.51399 |  0:26:46s
# epoch 40 | loss: 0.26949 | train_mae: 0.363   | train_rmse: 0.4778  | valid_mae: 0.36776 | valid_rmse: 0.48332 |  0:27:24s
# epoch 41 | loss: 0.25998 | train_mae: 0.3617  | train_rmse: 0.47104 | valid_mae: 0.36591 | valid_rmse: 0.47683 |  0:28:01s
# epoch 42 | loss: 0.27187 | train_mae: 0.40948 | train_rmse: 0.53105 | valid_mae: 0.41329 | valid_rmse: 0.53668 |  0:28:39s
# epoch 43 | loss: 0.26242 | train_mae: 0.35916 | train_rmse: 0.46935 | valid_mae: 0.36279 | valid_rmse: 0.47447 |  0:29:21s
# epoch 44 | loss: 0.26251 | train_mae: 0.36878 | train_rmse: 0.48078 | valid_mae: 0.37259 | valid_rmse: 0.48596 |  0:29:58s
# epoch 45 | loss: 0.25795 | train_mae: 0.35611 | train_rmse: 0.46583 | valid_mae: 0.36101 | valid_rmse: 0.47198 |  0:30:36s
# epoch 46 | loss: 0.24968 | train_mae: 0.35762 | train_rmse: 0.47345 | valid_mae: 0.3622  | valid_rmse: 0.47963 |  0:31:13s
# epoch 47 | loss: 0.25096 | train_mae: 0.35946 | train_rmse: 0.47562 | valid_mae: 0.3651  | valid_rmse: 0.48301 |  0:31:50s
# epoch 48 | loss: 0.24743 | train_mae: 0.35217 | train_rmse: 0.46017 | valid_mae: 0.35576 | valid_rmse: 0.46444 |  0:32:33s
# epoch 49 | loss: 0.2506  | train_mae: 0.35283 | train_rmse: 0.46552 | valid_mae: 0.35781 | valid_rmse: 0.47141 |  0:33:10s
# epoch 50 | loss: 0.23953 | train_mae: 0.35432 | train_rmse: 0.46856 | valid_mae: 0.35911 | valid_rmse: 0.47456 |  0:33:48s
# epoch 51 | loss: 0.23442 | train_mae: 0.35012 | train_rmse: 0.46102 | valid_mae: 0.35408 | valid_rmse: 0.46576 |  0:34:25s
# epoch 52 | loss: 0.2385  | train_mae: 0.35529 | train_rmse: 0.46482 | valid_mae: 0.35992 | valid_rmse: 0.47103 |  0:35:02s
# epoch 53 | loss: 0.2387  | train_mae: 0.34114 | train_rmse: 0.44774 | valid_mae: 0.34544 | valid_rmse: 0.45307 |  0:35:44s
# epoch 54 | loss: 0.23803 | train_mae: 0.34811 | train_rmse: 0.45646 | valid_mae: 0.35248 | valid_rmse: 0.46178 |  0:36:21s
# epoch 55 | loss: 0.23376 | train_mae: 0.35328 | train_rmse: 0.46707 | valid_mae: 0.3584  | valid_rmse: 0.47304 |  0:36:59s
# epoch 56 | loss: 0.23776 | train_mae: 0.3382  | train_rmse: 0.44398 | valid_mae: 0.34276 | valid_rmse: 0.44942 |  0:37:37s
# epoch 57 | loss: 0.24193 | train_mae: 0.3555  | train_rmse: 0.45764 | valid_mae: 0.36005 | valid_rmse: 0.46299 |  0:38:15s
# epoch 58 | loss: 0.22766 | train_mae: 0.33752 | train_rmse: 0.44183 | valid_mae: 0.34182 | valid_rmse: 0.44682 |  0:38:57s
# epoch 59 | loss: 0.22871 | train_mae: 0.34032 | train_rmse: 0.44386 | valid_mae: 0.34514 | valid_rmse: 0.44957 |  0:39:34s
# epoch 60 | loss: 0.24038 | train_mae: 0.35362 | train_rmse: 0.45824 | valid_mae: 0.35806 | valid_rmse: 0.4635  |  0:40:11s
# epoch 61 | loss: 0.24877 | train_mae: 0.35438 | train_rmse: 0.45568 | valid_mae: 0.35828 | valid_rmse: 0.46029 |  0:40:49s
# epoch 62 | loss: 0.23292 | train_mae: 0.33207 | train_rmse: 0.43767 | valid_mae: 0.33706 | valid_rmse: 0.44292 |  0:41:30s
# epoch 63 | loss: 0.22775 | train_mae: 0.40298 | train_rmse: 0.52647 | valid_mae: 0.40838 | valid_rmse: 0.53241 |  0:42:09s
# epoch 64 | loss: 0.2259  | train_mae: 0.33047 | train_rmse: 0.4337  | valid_mae: 0.33527 | valid_rmse: 0.43914 |  0:42:46s
# epoch 65 | loss: 0.24116 | train_mae: 0.34083 | train_rmse: 0.44801 | valid_mae: 0.34484 | valid_rmse: 0.45282 |  0:43:23s
# epoch 66 | loss: 0.24211 | train_mae: 0.36305 | train_rmse: 0.47302 | valid_mae: 0.36735 | valid_rmse: 0.47779 |  0:44:01s
# epoch 67 | loss: 0.23581 | train_mae: 0.33623 | train_rmse: 0.43841 | valid_mae: 0.34055 | valid_rmse: 0.44285 |  0:44:43s
# epoch 68 | loss: 0.2209  | train_mae: 0.35217 | train_rmse: 0.46135 | valid_mae: 0.35692 | valid_rmse: 0.46622 |  0:45:21s
# epoch 69 | loss: 0.22736 | train_mae: 0.33797 | train_rmse: 0.44476 | valid_mae: 0.34303 | valid_rmse: 0.45078 |  0:45:58s
# epoch 70 | loss: 0.21456 | train_mae: 0.34806 | train_rmse: 0.45629 | valid_mae: 0.35205 | valid_rmse: 0.46107 |  0:46:36s
# epoch 71 | loss: 0.21653 | train_mae: 0.33329 | train_rmse: 0.43838 | valid_mae: 0.33779 | valid_rmse: 0.44377 |  0:47:13s
# epoch 72 | loss: 0.21612 | train_mae: 0.33132 | train_rmse: 0.43337 | valid_mae: 0.33558 | valid_rmse: 0.43918 |  0:47:55s
# epoch 73 | loss: 0.21194 | train_mae: 0.34174 | train_rmse: 0.44776 | valid_mae: 0.34665 | valid_rmse: 0.45376 |  0:48:33s
# epoch 74 | loss: 0.22411 | train_mae: 0.34238 | train_rmse: 0.44759 | valid_mae: 0.34666 | valid_rmse: 0.45316 |  0:49:10s
# epoch 75 | loss: 0.2198  | train_mae: 0.33423 | train_rmse: 0.43923 | valid_mae: 0.33807 | valid_rmse: 0.44428 |  0:49:47s
# epoch 76 | loss: 0.21999 | train_mae: 0.35596 | train_rmse: 0.4667  | valid_mae: 0.35993 | valid_rmse: 0.47147 |  0:50:25s
# epoch 77 | loss: 0.23447 | train_mae: 0.33773 | train_rmse: 0.4426  | valid_mae: 0.34187 | valid_rmse: 0.44726 |  0:51:08s
# epoch 78 | loss: 0.23072 | train_mae: 0.31882 | train_rmse: 0.4201  | valid_mae: 0.32318 | valid_rmse: 0.42536 |  0:51:46s
# epoch 79 | loss: 0.22768 | train_mae: 0.34625 | train_rmse: 0.44436 | valid_mae: 0.35025 | valid_rmse: 0.44987 |  0:52:23s
# epoch 80 | loss: 0.23022 | train_mae: 0.32906 | train_rmse: 0.42834 | valid_mae: 0.33267 | valid_rmse: 0.43288 |  0:53:01s
# epoch 81 | loss: 0.22776 | train_mae: 0.35968 | train_rmse: 0.46615 | valid_mae: 0.36271 | valid_rmse: 0.46977 |  0:53:41s
# epoch 82 | loss: 0.21443 | train_mae: 0.32426 | train_rmse: 0.4251  | valid_mae: 0.32866 | valid_rmse: 0.43071 |  0:54:21s
# epoch 83 | loss: 0.21328 | train_mae: 0.34284 | train_rmse: 0.44906 | valid_mae: 0.34642 | valid_rmse: 0.45323 |  0:54:58s
# epoch 84 | loss: 0.20582 | train_mae: 0.34186 | train_rmse: 0.44076 | valid_mae: 0.34539 | valid_rmse: 0.44533 |  0:55:35s
# epoch 85 | loss: 0.21363 | train_mae: 0.33647 | train_rmse: 0.43598 | valid_mae: 0.34038 | valid_rmse: 0.44059 |  0:56:12s
# epoch 86 | loss: 0.22703 | train_mae: 0.32887 | train_rmse: 0.4331  | valid_mae: 0.33257 | valid_rmse: 0.43783 |  0:56:54s
# epoch 87 | loss: 0.20737 | train_mae: 0.33643 | train_rmse: 0.43986 | valid_mae: 0.34117 | valid_rmse: 0.44489 |  0:57:32s
# epoch 88 | loss: 0.20618 | train_mae: 0.3318  | train_rmse: 0.4367  | valid_mae: 0.3361  | valid_rmse: 0.44253 |  0:58:17s
# epoch 89 | loss: 0.22041 | train_mae: 0.35054 | train_rmse: 0.45543 | valid_mae: 0.35454 | valid_rmse: 0.46012 |  0:58:54s
# epoch 90 | loss: 0.20568 | train_mae: 0.33521 | train_rmse: 0.44124 | valid_mae: 0.33969 | valid_rmse: 0.44677 |  0:59:31s
# epoch 91 | loss: 0.2162  | train_mae: 0.34001 | train_rmse: 0.44534 | valid_mae: 0.34409 | valid_rmse: 0.45016 |  1:00:13s
# epoch 92 | loss: 0.20168 | train_mae: 0.32378 | train_rmse: 0.42472 | valid_mae: 0.3271  | valid_rmse: 0.42965 |  1:00:51s
# epoch 93 | loss: 0.20242 | train_mae: 0.32    | train_rmse: 0.41903 | valid_mae: 0.32402 | valid_rmse: 0.4243  |  1:01:28s
# epoch 94 | loss: 0.21116 | train_mae: 0.35863 | train_rmse: 0.46997 | valid_mae: 0.36244 | valid_rmse: 0.4754  |  1:02:05s
# epoch 95 | loss: 0.19902 | train_mae: 0.33017 | train_rmse: 0.43246 | valid_mae: 0.33427 | valid_rmse: 0.43783 |  1:02:43s
# epoch 96 | loss: 0.21653 | train_mae: 0.35586 | train_rmse: 0.45981 | valid_mae: 0.35925 | valid_rmse: 0.46463 |  1:03:25s
# epoch 97 | loss: 0.20393 | train_mae: 0.32168 | train_rmse: 0.42335 | valid_mae: 0.3248  | valid_rmse: 0.42753 |  1:04:02s
# epoch 98 | loss: 0.20683 | train_mae: 0.32421 | train_rmse: 0.42455 | valid_mae: 0.3278  | valid_rmse: 0.42882 |  1:04:40s
# epoch 99 | loss: 0.20398 | train_mae: 0.36931 | train_rmse: 0.47369 | valid_mae: 0.37251 | valid_rmse: 0.47743 |  1:05:16s
# epoch 100| loss: 0.19866 | train_mae: 0.32085 | train_rmse: 0.41808 | valid_mae: 0.32479 | valid_rmse: 0.42327 |  1:05:58s
# epoch 101| loss: 0.19719 | train_mae: 0.3373  | train_rmse: 0.44417 | valid_mae: 0.34151 | valid_rmse: 0.44879 |  1:06:37s
# epoch 102| loss: 0.19794 | train_mae: 0.32369 | train_rmse: 0.42671 | valid_mae: 0.32802 | valid_rmse: 0.43199 |  1:07:14s
# epoch 103| loss: 0.20272 | train_mae: 0.33718 | train_rmse: 0.44165 | valid_mae: 0.34194 | valid_rmse: 0.44739 |  1:07:53s
# epoch 104| loss: 0.20371 | train_mae: 0.31808 | train_rmse: 0.41547 | valid_mae: 0.32139 | valid_rmse: 0.41946 |  1:08:29s
# epoch 105| loss: 0.2053  | train_mae: 0.34081 | train_rmse: 0.44992 | valid_mae: 0.34523 | valid_rmse: 0.45486 |  1:09:12s
# epoch 106| loss: 0.20199 | train_mae: 0.33332 | train_rmse: 0.43659 | valid_mae: 0.33712 | valid_rmse: 0.44147 |  1:09:49s
# epoch 107| loss: 0.20231 | train_mae: 0.32065 | train_rmse: 0.42088 | valid_mae: 0.32398 | valid_rmse: 0.42437 |  1:10:26s
# epoch 108| loss: 0.19522 | train_mae: 0.32177 | train_rmse: 0.42365 | valid_mae: 0.32589 | valid_rmse: 0.42803 |  1:11:04s
# epoch 109| loss: 0.19348 | train_mae: 0.31626 | train_rmse: 0.41688 | valid_mae: 0.32061 | valid_rmse: 0.42201 |  1:11:41s
# epoch 110| loss: 0.19376 | train_mae: 0.32395 | train_rmse: 0.4229  | valid_mae: 0.32798 | valid_rmse: 0.428   |  1:12:23s
# epoch 111| loss: 0.20237 | train_mae: 0.31273 | train_rmse: 0.41192 | valid_mae: 0.3172  | valid_rmse: 0.41734 |  1:13:01s
# epoch 112| loss: 0.19251 | train_mae: 0.33144 | train_rmse: 0.43453 | valid_mae: 0.33489 | valid_rmse: 0.43831 |  1:13:38s
# epoch 113| loss: 0.20019 | train_mae: 0.31851 | train_rmse: 0.41579 | valid_mae: 0.32205 | valid_rmse: 0.41993 |  1:14:16s
# epoch 114| loss: 0.18877 | train_mae: 0.33571 | train_rmse: 0.44368 | valid_mae: 0.33887 | valid_rmse: 0.44651 |  1:14:53s
# epoch 115| loss: 0.19513 | train_mae: 0.31625 | train_rmse: 0.41827 | valid_mae: 0.31983 | valid_rmse: 0.4222  |  1:15:36s
# epoch 116| loss: 0.22555 | train_mae: 0.35779 | train_rmse: 0.46293 | valid_mae: 0.36199 | valid_rmse: 0.46825 |  1:16:13s
# epoch 117| loss: 0.22309 | train_mae: 0.32712 | train_rmse: 0.43067 | valid_mae: 0.33132 | valid_rmse: 0.4361  |  1:16:50s
# epoch 118| loss: 0.2172  | train_mae: 0.31656 | train_rmse: 0.41758 | valid_mae: 0.32102 | valid_rmse: 0.42348 |  1:17:27s
# epoch 119| loss: 0.21677 | train_mae: 0.3319  | train_rmse: 0.42947 | valid_mae: 0.33566 | valid_rmse: 0.43414 |  1:18:07s
# epoch 120| loss: 0.20823 | train_mae: 0.32525 | train_rmse: 0.42694 | valid_mae: 0.32972 | valid_rmse: 0.43306 |  1:18:47s
# epoch 121| loss: 0.19861 | train_mae: 0.32689 | train_rmse: 0.42783 | valid_mae: 0.33068 | valid_rmse: 0.43184 |  1:19:24s
# epoch 122| loss: 0.19674 | train_mae: 0.31082 | train_rmse: 0.41066 | valid_mae: 0.31493 | valid_rmse: 0.41482 |  1:20:01s
# epoch 123| loss: 0.20999 | train_mae: 0.32954 | train_rmse: 0.43169 | valid_mae: 0.33376 | valid_rmse: 0.43576 |  1:20:38s
# epoch 124| loss: 0.21691 | train_mae: 0.32173 | train_rmse: 0.42194 | valid_mae: 0.32612 | valid_rmse: 0.4276  |  1:21:20s
# epoch 125| loss: 0.1956  | train_mae: 0.31757 | train_rmse: 0.41645 | valid_mae: 0.32178 | valid_rmse: 0.42162 |  1:22:00s
# epoch 126| loss: 0.19196 | train_mae: 0.34063 | train_rmse: 0.44198 | valid_mae: 0.3444  | valid_rmse: 0.44617 |  1:22:37s
# epoch 127| loss: 0.19551 | train_mae: 0.33878 | train_rmse: 0.44387 | valid_mae: 0.34236 | valid_rmse: 0.44769 |  1:23:15s
# epoch 128| loss: 0.18918 | train_mae: 0.31626 | train_rmse: 0.41534 | valid_mae: 0.3203  | valid_rmse: 0.42056 |  1:23:51s
# epoch 129| loss: 0.19109 | train_mae: 0.30595 | train_rmse: 0.40212 | valid_mae: 0.30864 | valid_rmse: 0.40547 |  1:24:33s
# epoch 130| loss: 0.18759 | train_mae: 0.32909 | train_rmse: 0.43083 | valid_mae: 0.33275 | valid_rmse: 0.43503 |  1:25:11s
# epoch 131| loss: 0.19578 | train_mae: 0.31233 | train_rmse: 0.40874 | valid_mae: 0.31648 | valid_rmse: 0.41362 |  1:25:48s
# epoch 132| loss: 0.18898 | train_mae: 0.31049 | train_rmse: 0.40686 | valid_mae: 0.31362 | valid_rmse: 0.41075 |  1:26:24s
# epoch 133| loss: 0.18975 | train_mae: 0.30798 | train_rmse: 0.40659 | valid_mae: 0.31238 | valid_rmse: 0.41197 |  1:27:02s
# epoch 134| loss: 0.18856 | train_mae: 0.30904 | train_rmse: 0.407   | valid_mae: 0.31259 | valid_rmse: 0.41124 |  1:27:44s
# epoch 135| loss: 0.19172 | train_mae: 0.33355 | train_rmse: 0.43317 | valid_mae: 0.33675 | valid_rmse: 0.43661 |  1:28:21s
# epoch 136| loss: 0.19104 | train_mae: 0.30992 | train_rmse: 0.40723 | valid_mae: 0.31318 | valid_rmse: 0.41065 |  1:28:59s
# epoch 137| loss: 0.19301 | train_mae: 0.32946 | train_rmse: 0.43102 | valid_mae: 0.33396 | valid_rmse: 0.43616 |  1:29:36s
# epoch 138| loss: 0.19345 | train_mae: 0.33254 | train_rmse: 0.43686 | valid_mae: 0.33666 | valid_rmse: 0.44072 |  1:30:14s
# epoch 139| loss: 0.21859 | train_mae: 0.31324 | train_rmse: 0.41379 | valid_mae: 0.31659 | valid_rmse: 0.41777 |  1:30:56s
# epoch 140| loss: 0.2074  | train_mae: 0.32737 | train_rmse: 0.42259 | valid_mae: 0.3309  | valid_rmse: 0.42682 |  1:31:32s
# epoch 141| loss: 0.20712 | train_mae: 0.33105 | train_rmse: 0.42627 | valid_mae: 0.33461 | valid_rmse: 0.43012 |  1:32:10s
# epoch 142| loss: 0.19048 | train_mae: 0.33093 | train_rmse: 0.43117 | valid_mae: 0.33433 | valid_rmse: 0.43523 |  1:32:47s
# epoch 143| loss: 0.18976 | train_mae: 0.32586 | train_rmse: 0.42823 | valid_mae: 0.32948 | valid_rmse: 0.43178 |  1:33:28s
# epoch 144| loss: 0.19386 | train_mae: 0.33758 | train_rmse: 0.44066 | valid_mae: 0.34052 | valid_rmse: 0.44359 |  1:34:07s
# epoch 145| loss: 0.18839 | train_mae: 0.31861 | train_rmse: 0.41883 | valid_mae: 0.32214 | valid_rmse: 0.42315 |  1:34:45s
# epoch 146| loss: 0.18508 | train_mae: 0.35223 | train_rmse: 0.45735 | valid_mae: 0.35546 | valid_rmse: 0.46094 |  1:35:22s
# epoch 147| loss: 0.18963 | train_mae: 0.31949 | train_rmse: 0.41795 | valid_mae: 0.32316 | valid_rmse: 0.42206 |  1:35:59s
# epoch 148| loss: 0.19095 | train_mae: 0.32098 | train_rmse: 0.42168 | valid_mae: 0.32461 | valid_rmse: 0.42581 |  1:36:41s
# epoch 149| loss: 0.18315 | train_mae: 0.31599 | train_rmse: 0.41421 | valid_mae: 0.31984 | valid_rmse: 0.41878 |  1:37:21s
#
# Early stopping occurred at epoch 149 with best_epoch = 129 and best_valid_rmse = 0.40547
# c:\Users\User\AppData\Local\Programs\Python\Python310\lib\site-packages\pytorch_tabnet\callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)

# %%
valid_rmse = tabnetReg.history['valid_rmse']

epochs = range(len(valid_rmse))

plt.figure(figsize=(10,5))
plt.plot(epochs, valid_rmse, label='Validation RMSE')
plt.title('Validation RMSE over epochs')
plt.xlabel('Epochs')
plt.ylabel('RMSE')
plt.legend()
plt.show()

# %%
y_test_pred_linReg = linreg.predict(X_test)
y_test_pred_xgb = xgbreg.predict(X_test)
y_test_pred_linReg_boxcox = linreg_withBoxCox.predict(X_test)
y_test_pred_xgb_boxcox =  xgbreg_withBoxCox.predict(X_test)
y_test_pred_tabnet_boxcox = tabnetReg.predict(X_test.values)

y_test_pred_linReg_original_scale = inv_boxcox(y_test_pred_linReg_boxcox, lambda_boxcox)
y_test_pred_xgb_original_scale = inv_boxcox(y_test_pred_xgb_boxcox, lambda_boxcox)
y_test_pred_tabnet_original_scale = inv_boxcox(y_test_pred_tabnet_boxcox, lambda_boxcox)

print("Goodness of Fit on Test Dataset:")
print()
print("Linear Regression Model:")
print("Explained Variance (R^2):", r2_score(y_test, y_test_pred_linReg))
print("Root Mean Squared Error (RMSE):", math.sqrt(mean_squared_error(y_test, y_test_pred_linReg)))
print()

print("XGBoost Model:")
print("Explained Variance (R^2):", r2_score(y_test, y_test_pred_xgb))
print("Root Mean Squared Error (RMSE):", math.sqrt(mean_squared_error(y_test, y_test_pred_xgb)))
print()

print("Linear Regression Model (with log transformation):")
print("Explained Variance (R^2):", r2_score(y_test, y_test_pred_linReg_original_scale))
print("Root Mean Squared Error (RMSE):", math.sqrt(mean_squared_error(y_test, y_test_pred_linReg_original_scale)))
print()

print("XGBoost Model (with log transformation):")
print("Explained Variance (R^2):", r2_score(y_test, y_test_pred_xgb_original_scale))
print("Root Mean Squared Error (RMSE):", math.sqrt(mean_squared_error(y_test, y_test_pred_xgb_original_scale)))
print()


print("Tabnet Model (with log transformation):")
print("Explained Variance (R^2):", r2_score(y_test, y_test_pred_tabnet_original_scale))
print("Root Mean Squared Error (RMSE):", math.sqrt(mean_squared_error(y_test, y_test_pred_tabnet_original_scale)))
print()

# Plot the Predictions versus True values
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.scatter(y_test, y_test_pred_linReg, alpha= 0.5)
plt.plot(y_test, y_test, 'r--', linewidth=2)
plt.xlabel("True values of the Response Variable (Test)")
plt.ylabel("Predicted values of the Response Variable (Test)")
plt.title("Linear Regression Model")

plt.subplot(1, 2, 2)
plt.scatter(y_test, y_test_pred_xgb, alpha= 0.5)
plt.plot(y_test, y_test, 'r--', linewidth=2)
plt.xlabel("True values of the Response Variable (Test)")
plt.ylabel("Predicted values of the Response Variable (Test)")
plt.title("XGBoost Model")

plt.figure(figsize=(18, 6))

plt.subplot(1, 3, 1)
plt.scatter(y_test, y_test_pred_linReg_original_scale, alpha=0.5)
plt.plot(y_test, y_test, 'r--', linewidth=2)
plt.xlabel("True values of the Response Variable (Test)")
plt.ylabel("Predicted values of the Response Variable (Test)")
plt.title("Linear Regression model with transformation")

plt.subplot(1, 3, 2)
plt.scatter(y_test, y_test_pred_xgb_original_scale, alpha=0.5)
plt.plot(y_test, y_test, 'r--', linewidth=2)
plt.xlabel("True values of the Response Variable (Test)")
plt.ylabel("Predicted values of the Response Variable (Test)")
plt.title("XGBoost model with transformation")

plt.subplot(1, 3, 3)
plt.scatter(y_test, y_test_pred_tabnet_original_scale, alpha=0.5)
plt.plot(y_test, y_test, 'r--', linewidth=2)
plt.xlabel("True values of the Response Variable (Test)")
plt.ylabel("Predicted values of the Response Variable (Test)")
plt.title("Tabnet model")
plt.tight_layout()
plt.show()
# Out:
# Goodness of Fit on Test Dataset:
#
# Linear Regression Model:
# Explained Variance (R^2): 0.7001593205392791
# Root Mean Squared Error (RMSE): 89638.0128157399
#
# XGBoost Model:
# Explained Variance (R^2): 0.9568476342909792
# Root Mean Squared Error (RMSE): 34005.50652967173
#
# Linear Regression Model (with log transformation):
# Explained Variance (R^2): 0.7003549169166182
# Root Mean Squared Error (RMSE): 89608.7710683115
#
# XGBoost Model (with log transformation):
# Explained Variance (R^2): 0.955981841427905
# Root Mean Squared Error (RMSE): 34344.9492299273
#
# Tabnet Model (with log transformation):
# Explained Variance (R^2): 0.9449388727898873
# Root Mean Squared Error (RMSE): 38412.227507265445

# %%
linear_regression_coefficients = linreg_withBoxCox.coef_
linear_regression_intercept = linreg_withBoxCox.intercept_
linear_regression_withLog_coefficients = linreg_withBoxCox.coef_
linear_regression_withLog_intercept = linreg_withBoxCox.intercept_


xgboost_feature_importances = xgbreg.feature_importances_
xgboost_withLog_feature_importances = xgbreg_withBoxCox.feature_importances_

tabnet_feature_importances = tabnetReg.feature_importances_

# %%
# Create a DataFrame to hold the feature importances
df_feature_importance = pd.DataFrame({
    'Feature': features,
    'Linear Regression': linear_regression_coefficients,
    'Linear Regression (with transformation)': linear_regression_withLog_coefficients,
    'XGBoost': xgboost_feature_importances,
    'XGBoost (with transformation)': xgboost_withLog_feature_importances,
    'TabNet': tabnet_feature_importances
})

df_feature_importance.sort_values(by='XGBoost (with transformation)', ascending=False, inplace=True)

# Plotting
fig, axes = plt.subplots(nrows=1, ncols=5, figsize=(25, 5))
df_feature_importance.plot(kind='bar', x='Feature', y='Linear Regression', ax=axes[0], legend=False)
df_feature_importance.plot(kind='bar', x='Feature', y='Linear Regression (with transformation)', ax=axes[1], legend=False)
df_feature_importance.plot(kind='bar', x='Feature', y='XGBoost', ax=axes[2], legend=False)
df_feature_importance.plot(kind='bar', x='Feature', y='XGBoost (with transformation)', ax=axes[3], legend=False)
df_feature_importance.plot(kind='bar', x='Feature', y='TabNet', ax=axes[4], legend=False)

axes[0].set_title('Linear Regression Coefficients')
axes[1].set_title('Linear Regression Coefficients (with transformation)')
axes[2].set_title('XGBoost Feature Importances')
axes[3].set_title('XGBoost Feature Importances (with transformation)')
axes[4].set_title('TabNet Feature Importances')

axes[0].set_ylabel('Coefficient value / Importance score')

# Find the global maximum importance for XGBoost and TabNet
xgb_max = max(max(xgboost_feature_importances), max(xgboost_withLog_feature_importances))
tabnet_max = max(tabnet_feature_importances)
common_max = max(xgb_max, tabnet_max)

# Set the same y-axis limits for the XGBoost and TabNet plots
for ax in axes[2:]:
    ax.set_ylim(0, common_max + 0.1 * common_max)

plt.tight_layout()
plt.show()

# %%
for category, mappings in encoding_mappings.items():
    print(f"{category}:")
    for key, value in mappings.items():
        print(f"  {key}: {value}")
    print()
# Out:
# town:
#   GEYLANG: 0
#   ANG MO KIO: 1
#   YISHUN: 2
#   BEDOK: 3
#   TOA PAYOH: 4
#   BUKIT BATOK: 5
#   QUEENSTOWN: 6
#   CLEMENTI: 7
#   JURONG EAST: 8
#   JURONG WEST: 9
#   WOODLANDS: 10
#   KALLANG/WHAMPOA: 11
#   HOUGANG: 12
#   BUKIT PANJANG: 13
#   SERANGOON: 14
#   CHOA CHU KANG: 15
#   SEMBAWANG: 16
#   CENTRAL AREA: 17
#   TAMPINES: 18
#   MARINE PARADE: 19
#   BUKIT MERAH: 20
#   SENGKANG: 21
#   PASIR RIS: 22
#   PUNGGOL: 23
#   BISHAN: 24
#   BUKIT TIMAH: 25
#
# flat_type:
#   1 ROOM: 0
#   2 ROOM: 1
#   3 ROOM: 2
#   4 ROOM: 3
#   5 ROOM: 4
#   EXECUTIVE: 5
#   MULTI-GENERATION: 6
#
# flat_model:
#   Standard: 0
#   2-room: 1
#   Simplified: 2
#   New Generation: 3
#   Model A2: 4
#   Model A: 5
#   Improved: 6
#   Premium Apartment: 7
#   Adjoined flat: 8
#   Apartment: 9
#   Model A-Maisonette: 10
#   Improved-Maisonette: 11
#   Maisonette: 12
#   Multi Generation: 13
#   3Gen: 14
#   Terrace: 15
#   Premium Maisonette: 16
#   DBSS: 17
#   Type S1: 18
#   Premium Apartment Loft: 19
#   Type S2: 20

# %%
new_sample = {
    'Year': 2034, #'Year' and 'Month' represent when the user wants to sell the hdb
    'Month': 2,
    'floor_area_sqm': 100,
    'lease_commence_date': 2006,
    'average_storey': 10,
    'town': 'BEDOK',
    'flat_type': 'EXECUTIVE',
    'flat_model': 'Type S2'
}

new_sample_df = pd.DataFrame([new_sample])

encoded_user_input = encode_new_input(new_sample_df, encoding_mappings)
encoded_user_input_array = encoded_user_input.to_numpy()

#annoying coz clf.predict take in array but linreg.predict take in df
predicted_resale_price_tabnet = inv_boxcox(tabnetReg.predict(encoded_user_input_array), lambda_boxcox)
predicted_resale_price_linreg = linreg.predict(encoded_user_input)
predicted_resale_price_linreg_withboxcox = inv_boxcox(linreg_withBoxCox.predict(encoded_user_input),lambda_boxcox)
predicted_resale_price_xgb = xgbreg.predict(encoded_user_input)
predicted_resale_price_xgb_withboxcox = inv_boxcox(xgbreg_withBoxCox.predict(encoded_user_input),lambda_boxcox)

print(f"Predicted Resale Value for Linear Regression:                       {predicted_resale_price_linreg[0]}")
print(f"Predicted Resale Value for Linear Regression with transformation:   {predicted_resale_price_linreg_withboxcox[0]}")
print(f"Predicted Resale Value for XGBoost:                                 {predicted_resale_price_xgb[0]}")
print(f"Predicted Resale Value for XGBoost with transformation:             {predicted_resale_price_xgb_withboxcox[0]}")
print(f"Predicted Resale Value for Tabnet:                                  {predicted_resale_price_tabnet[0]}")
# Out:
# Predicted Resale Value for Linear Regression:                       844876.3564935029
# Predicted Resale Value for Linear Regression with transformation:   865747.9675511688
# Predicted Resale Value for XGBoost:                                 1160312.25
# Predicted Resale Value for XGBoost with transformation:             1158700.75
# Predicted Resale Value for Tabnet:                                  [1440169.1]

# %%
print(tabnetReg.history.history.keys())
# Out:
# dict_keys(['loss', 'lr', 'train_mae', 'train_rmse', 'valid_mae', 'valid_rmse'])

# %%
from sklearn.model_selection import cross_val_score
from xgboost import XGBRegressor
import numpy as np

# Assuming you have a dataset with features X and target y
# Make sure these are your full datasets, not just the test set
X = X_test
y = y_test_log
# Initialize the XGBoost regressor
# xgb_reg = XGBRegressor()

# Define the number of folds for cross-validation
num_folds = 5

# Perform cross-validation using the mean squared error, which is a common metric for regression
xgb_scores = cross_val_score(xgbreg_withLog, X, y, cv=num_folds, scoring='neg_mean_squared_error')  # Change scoring if needed

# The scores are negative due to scikit-learn's convention for scoring (higher is better)
# Convert to positive values
xgb_scores = -xgb_scores

# Calculate the mean and standard deviation of the scores
xgb_mean = np.mean(xgb_scores)
xgb_std = np.std(xgb_scores)

print(f'XGBoost Mean Squared Error: {xgb_mean} (+/- {xgb_std})')
# Out:
# XGBoost Mean Squared Error: 0.006111584997334623 (+/- 0.00010118368872882433)

# %%
from sklearn.model_selection import KFold

# Assuming you have a dataset with features X and target y
X = X_test.values
y = y_test_log.values.reshape(-1,1)

# Convert the dataset to a PyTorch Tensor (if using PyTorch TabNet)
X_tensor = torch.from_numpy(X.astype(np.float64))
y_tensor = torch.from_numpy(y.astype(np.float64))

# Define the number of folds for cross-validation
num_folds = 5
kf = KFold(n_splits=num_folds, shuffle=True)

tabnet_scores = []

# Start the cross-validation loop
for train_index, test_index in kf.split(X):
    X_train, X_valid = X_tensor[train_index], X_tensor[test_index]
    y_train, y_valid = y_tensor[train_index], y_tensor[test_index]

    # Evaluate the model using ROC-AUC or your metric of choice
    score = tabnetReg.best_cost  # This might be different based on the library you use
    tabnet_scores.append(score)

# Calculate the mean and standard deviation of the scores
tabnet_mean = np.mean(tabnet_scores)
tabnet_std = np.std(tabnet_scores)

print(f'TabNet ROC-AUC: {tabnet_mean} (+/- {tabnet_std})')
# Out:
# TabNet ROC-AUC: 0.08785519310736979 (+/- 0.0)
